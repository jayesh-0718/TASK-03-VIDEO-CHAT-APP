# %% [markdown]
# # Client Side

# %%
# importing library

import socket
import numpy as np
import cv2 as cv
import threading

# %%
# client program socket to connect to the server program
s = socket.socket()
s.bind(("", 9999))  # empty indicates local system
server_ip = input("Enter server ip: ")
server_port = input("Enter server port number: ")

s.connect((server_ip, int(server_port))) 
s.send(b"connected")  # sending string as data
camera = cv.VideoCapture(0) # starting the camera i.e., laptop webcam


# function for client to work as receiver
def receiver():
    framesLost = 0
    print("Entered")
    while True:
        framesLost += 1 # counting frame
        data = s.recv(100000000)  # receiving data with the size limit
        if(data == b'finished'): # to stop receiving and stop camera
            print("Finished")
            camera.release()
            s.close()
        else:  # converting the byte data into numpy array
            photo =  np.frombuffer(data, dtype=np.uint8)
            if len(photo) == 640*480*3: # changing the array shape and getting the video
                cv.imshow('From Server', photo.reshape(480, 640, 3))
                if cv.waitKey(1) == 13: # camera release condition
                    s.send(b'finished')
                    camera.release()
                    cv.destroyAllWindows()
                    break
            else:
                print("Lost {} frames".format(framesLost) ) #counting the lost frames during video exchange

# function for client to send the data of the video             
def sender():
    while True: # reading the camera data, resizing and sending it as bytes 
        status, photo = camera.read()
        photo = cv.resize(photo, (640, 480))
        print(photo.shape)
        if status:
            s.send(np.ndarray.tobytes(photo))
        else: print("Could not get frame")
    camera.release()

# threads to run both the functions
threading.Thread(target=receiver).start()
threading.Thread(target=sender).start()
# Out:
# Enter server ip: 192.168.1.7
# Enter server port number: 1234
# Entered
# Lost 1 frames
# Lost 2 frames
# Lost 3 frames
# Lost 4 frames
# Lost 5 frames
# Lost 6 frames
# Lost 7 frames
# Lost 8 frames
# Lost 9 frames
# Lost 10 frames
# Lost 11 frames
# Lost 12 frames
# Lost 13 frames
# Lost 14 frames
# Lost 15 frames
# Lost 16 frames
# Lost 17 frames
# Lost 21 frames
# Lost 22 frames
# Lost 23 frames
# Lost 24 frames
# Lost 25 frames
# Lost 26 frames
# Lost 31 frames
# Lost 32 frames
# Lost 34 frames
# Lost 35 frames
# Lost 39 frames
# Lost 40 frames
# Lost 45 frames
# Lost 46 frames
# Lost 47 frames
# Lost 48 frames
# Lost 51 frames
# Lost 52 frames
# Lost 53 frames
# Lost 54 frames
# Lost 56 frames
# Lost 57 frames
# Lost 58 frames
# Lost 59 frames
# Lost 61 frames
# Lost 62 frames
# Lost 63 frames
# Lost 64 frames
# Lost 65 frames
# Lost 66 frames
# Lost 70 frames
# Lost 71 frames
# Lost 72 frames
# Lost 73 frames
# Lost 75 frames
# Lost 76 frames
# Lost 77 frames
# Lost 78 frames
# Lost 79 frames
# Lost 80 frames
# Lost 81 frames
# Lost 82 frames
# Lost 84 frames
# Lost 85 frames
# Lost 89 frames
# Lost 90 frames
# Lost 93 frames
# Lost 94 frames
# Lost 95 frames
# Lost 96 frames
# Lost 97 frames
# Lost 98 frames
# Lost 99 frames
# Lost 100 frames
# Lost 104 frames
# Lost 105 frames
# Lost 108 frames
# Lost 109 frames
# Lost 111 frames
# Lost 112 frames
# Lost 114 frames
# Lost 115 frames
# Lost 117 frames
# Lost 118 frames
# Lost 121 frames
# Lost 122 frames
# Lost 129 frames
# Lost 130 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 140 frames
# (480, 640, 3)
# Lost 141 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 142 frames
# (480, 640, 3)
# Lost 143 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 145 frames
# (480, 640, 3)
# Lost 146 frames
# (480, 640, 3)
# Lost 147 frames(480, 640, 3)
#
# Lost 148 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 149 frames
# Lost 150 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 151 frames
# (480, 640, 3)
# Lost 152 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 153 frames
# (480, 640, 3)
# Lost 154 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 155 frames
# Lost 156 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 157 frames
# (480, 640, 3)
# Lost 158 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 159 frames
# Lost 160 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 163 frames
# (480, 640, 3)
# Lost 164 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 169 frames
# Lost 170 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 173 frames
# (480, 640, 3)
# Lost 174 frames(480, 640, 3)
#
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 180 frames
# (480, 640, 3)
# Lost 181 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 184 frames
# Lost 185 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 187 frames
# (480, 640, 3)
# Lost 188 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 192 frames
# (480, 640, 3)
# Lost 193 frames
# Lost 194 frames
# (480, 640, 3)
# Lost 195 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 200 frames
# Lost 201 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 204 frames
# Lost 205 frames
# (480, 640, 3)
# Lost 206 frames
# Lost 207 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)Lost 208 frames
#
# Lost 209 frames
# (480, 640, 3)
# Lost 210 frames
# Lost 211 frames
# (480, 640, 3)
# Lost 212 frames
# Lost 213 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 216 frames
# Lost 217 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 218 frames
# Lost 219 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 223 frames
# (480, 640, 3)
# Lost 224 frames
# (480, 640, 3)
# (480, 640, 3)
# Lost 225 frames
# (480, 640, 3)
# Lost 226 frames
# Lost 227 frames
# Lost 228 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Lost 231 frames
# (480, 640, 3)
# Lost 232 frames
# (480, 640, 3)
# (480, 640, 3)
# (480, 640, 3)
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "C:\Users\JayKD\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\JayKD\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-c74b91923712>", line 39, in sender
# cv2.error: OpenCV(4.5.2) C:\Users\runneradmin\AppData\Local\Temp\pip-req-build-vi271kac\opencv\modules\imgproc\src\resize.cpp:4051: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
